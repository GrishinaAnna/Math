# %% [markdown]
# **4. Задание:**
# Постройте на одном графике две кривые y(x) для функции двух переменной y(k,x)=cos(k∙x), взяв для одной кривой значение k=1, а для другой – любое другое k, не равное 1.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(1, 15, 100)
k = 2
plt.plot(x, np.cos(x), label = 'cos(x)')
plt.plot(x, np.cos(k*x), label = 'cos(k*x)')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.title ('График функции y(x)')
plt.show()
